# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from pathlib import Path
import os
import sys
import glob
import time
from PIL import Image

# %matplotlib inline

# %%
folder_path = "D:\\Code\\research\\task1\\AllKanjiPositionAN" #絶対パスの指定

path = glob.glob( os.path.join( folder_path, "*.jpg" ) )
print(path) #ここで半角英数字以外がないか確認すること
img = cv2.imread( path[0] )
print( np.array( img ).shape )
data = [ cv2.imread(p,cv2.IMREAD_GRAYSCALE) for p in path ]

print(data)
# Out:
# ['D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0001_Pagina_01_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0001_Pagina_07_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0001_Pagina_10_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0001_Pagina_13_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0001_Pagina_14_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0001_Pagina_16_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0001_Pagina_18_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0001_Pagina_25_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0001_Pagina_30_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0002_Pagina_02_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0002_Pagina_05_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0002_Pagina_06_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0002_Pagina_11_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0002_Pagina_12_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0002_Pagina_13_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0002_Pagina_15_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0002_Pagina_19_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0002_Pagina_22_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0003_Pagina_42_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0004_Pagina_01_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0004_Pagina_03_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0004_Pagina_15_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0004_Pagina_20_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0004_Pagina_28_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0034_Pagina_30_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0034_Pagina_31_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0034_Pagina_36_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0034_Pagina_37_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0035_Pagina_01_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0035_Pagina_06_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0035_Pagina_09_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0035_Pagina_11_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0035_Pagina_14_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0035_Pagina_18_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0035_Pagina_20_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0035_Pagina_28_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0035_Pagina_35_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0036_Pagina_01_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0036_Pagina_02_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0036_Pagina_09_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0036_Pagina_11_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0036_Pagina_13_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositionAN\\KPsakuma-0036_Pagina_18_Imagen_0001AN.jpg', 'D:\\Code\\research\\task1\\AllKanjiPositio ...
# (3698, 5128, 3)
# [array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ...,   0,   0,   0],
#        [255, 255, 255, ...,   0,   0,   0],
#        [255, 255, 255, ...,   0,   0,   0]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        [255, 255, 255, ..., 254, 254, 254],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [254, 254, 254, ...,   0,   0,   0],
#        [254, 254, 254, ...,   0,   0,   0],
#        [254, 254, 254, ...,   0,   0,   0]], dtype=uint8), array([[254, 254, 254, ...,   0,   0,   0],
#        [254, 254, 254, ...,   0,   0,   0],
#        [254, 254, 254, ...,   0,   0,   0],
#        ...,
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254]], dtype=uint8), array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)]

# %%
def list_from_mask(images):
    """Convert mask location information to YOLO format

    Parameters
    ----------
    images : ndarray
        taget images

    Returns
    -------
    images_box: list
        List of coordinates converted to YOLO format

    """
    images_box = []
    for img in images:
        img[img<=10]=0
        img[img>10]=255
        imgheight,imgwidth = img.shape[:2]
        _, _, stats, centroids = cv2.connectedComponentsWithStats(255 - img)
        img_box = []

        for i in range(1,len(centroids)):
            x_center = round((centroids[i][0]/imgwidth), 6)
            y_center = round((centroids[i][1]/imgheight), 6)
            width = round((stats[i][2]/imgwidth), 6)
            height = round((stats[i][3]/imgheight), 6)
            img_box.append([1,x_center,y_center,width,height])

        images_box.append(img_box)

    return images_box

# %%
def draw_box(images):
    """Display a frame of recognized characters in the image

    Parameters
    ----------
    images : ndarray
        taget images

    Returns
    -------
    stats_show : ndarray
        Image displaying a frame

    """
    print("in function ")
    threshold = 500
    for i, img in enumerate(images):
        img[img<=10]=0
        img[img>10]=255
        img_color = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
        _, _, stats, centroids = cv2.connectedComponentsWithStats(255 - img)

        for j in range(1,len(centroids)):
            left_top = (stats[j][0], stats[j][1])
            width = stats[j][2]
            height = stats[j][3]
            if stats[j][4] > threshold:
                right_bottom = (stats[j][0] + width, stats[j][1] + height)
                stats_show = cv2.rectangle(img_color, left_top, right_bottom, (0,255,0), 2)

        cv2.imwrite('./output3/out' + str(i) +'.jpg', img_color)

# %%
images_box = list_from_mask(data)
print(images_box[0][0])
# Out:
# [1, 0.520574, 0.495181, 1.0, 1.0]

# %%
draw_box(data)
# Out:
# in function

# %% [markdown]
# ファイル書き込み

# %%
for i,image in enumerate(images_box):
    path_w = ('D:\\Code\\research\\task1\\outputtxt2\\testyolo_{}.txt').format(i)

    with open(path_w, mode='w') as f:
        for sub in image:
            f.write(' '.join(map(str, sub)) + '\n')
